# %% [markdown]
# # 4 - Influential Classification Models (and Tools)
#
# ## Introduction
#
# This Notebook (3) will continue on from the previous sections. This notebook will go through the process of __Extension into Multiple experiments to improve model testing results__.
#
# ## Dataset:
#
# For this part of the project, the CIFAR-100 dataset will be used, it is a collection of of 60,000 32x32 images that have 100 classes. CIFAR-100 was originally collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton. It iss also a subset of the 80 million tiny images dataset. There are 500 training images and 100 testing images per class. The 100 classes in the CIFAR-100 are grouped into 20 superclasses.
#
# Source: https://www.cs.toronto.edu/~kriz/cifar.html
#
# Further, the TensorFlow team offers a python package called "tensorflow_datasets" that provides the helper function to download tthis dataset as well as other more common ones. For the purposes of this project, the CIFAR-100 dataset will be download with this package.
#
# Source: https://www.tensorflow.org/datasets/catalog/cifar100
#
# ## Requirements:
# - Tensorflow 2.0 (GPU is better)
# - Tensorflow-Hub
# - Keras (GPU is better)
#
# ### Import the required libraries:

# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import timeit

# %%
import os
# from IPython.display import display, Image
# import matplotlib.pyplot as plt

# %matplotlib inline

# Set up the working directory for the images:
image_folderName = 'Description Images'
image_path = os.path.abspath(image_folderName) + '/'

# %%
# Set the random set seed number: for reproducibility.
Seed_nb = 42

# %% [markdown]
# ### GPU Information:

# %%
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
devices = sess.list_devices()
devices
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2070 SUPER, pci bus id: 0000:09:00.0, compute capability: 7.5
# [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456, 7388009113115316974),
#  _DeviceAttributes(/job:localhost/replica:0/task:0/device:GPU:0, GPU, 6586313605, 4859414560361713713)]

# %% [markdown]
# ## 1 - Data Preparation:
#
# To use the TensorFlow package, please ensure to install it: "pip install tensorflow-datasets" or use the Anaconda Navigator.
#
# ## 1.1 - Download the Dataset:

# %%
import tensorflow_datasets as tfds

# %%
# Show the different types of datasets available:
tfds.list_builders()
# Out:
# ['abstract_reasoning',
#  'aflw2k3d',
#  'amazon_us_reviews',
#  'bair_robot_pushing_small',
#  'bigearthnet',
#  'binarized_mnist',
#  'binary_alpha_digits',
#  'caltech101',
#  'caltech_birds2010',
#  'caltech_birds2011',
#  'cats_vs_dogs',
#  'celeb_a',
#  'celeb_a_hq',
#  'chexpert',
#  'cifar10',
#  'cifar100',
#  'cifar10_corrupted',
#  'clevr',
#  'cnn_dailymail',
#  'coco',
#  'coco2014',
#  'coil100',
#  'colorectal_histology',
#  'colorectal_histology_large',
#  'curated_breast_imaging_ddsm',
#  'cycle_gan',
#  'deep_weeds',
#  'definite_pronoun_resolution',
#  'diabetic_retinopathy_detection',
#  'downsampled_imagenet',
#  'dsprites',
#  'dtd',
#  'dummy_dataset_shared_generator',
#  'dummy_mnist',
#  'emnist',
#  'eurosat',
#  'fashion_mnist',
#  'flores',
#  'food101',
#  'gap',
#  'glue',
#  'groove',
#  'higgs',
#  'horses_or_humans',
#  'image_label_folder',
#  'imagenet2012',
#  'imagenet2012_corrupted',
#  'imdb_reviews',
#  'iris',
#  'kitti',
#  'kmnist',
#  'lfw',
#  'lm1b',
#  'lsun',
#  'mnist',
#  'mnist_corrupted',
#  'moving_mnist',
#  'multi_nli',
#  'nsynth',
#  'omniglot',
#  'open_images_v4',
#  'oxford_flowers102',
#  'oxford_iiit_pet',
#  'para_crawl',
#  'patch_camelyon',
#  'pet_finder',
#  'quickdraw_bitmap',
#  'resisc45',
#  'rock_paper_scissors',
#  'rock_you',
#  'scene_parse150',
#  'shapes3d',
#  'smallnorb',
#  'snli',
#  'so2sat',
#  'squad',
#  'stanford_dogs',
#  'stanford_online_products',
#  'starcraft_video',
#  'sun397',
#  'super_glue',
#  'svhn_cropped',
#  'ted_hrlr_translate',
#  'ted_multi_translate',
#  'tf_flowers',
#  'titanic',
#  'trivia_qa',
#  'uc_merced',
#  'ucf101',
#  'visual_domain_decathlon',
#  'voc2007',
#  'wikipedia',
#  'wmt14_translate',
#  'wmt15_translate',
#  'wmt16_translate',
#  'wmt17_translate',
#  'wmt18_translate',
#  'wmt19_translate',
#  'wmt_t2t_translate',
#  'wmt_translate',
#  'xnli']

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
# Select the CIFAR-100 dataset:
cifar_builder = tfds.builder("cifar100")
cifar_builder.download_and_prepare()

print(cifar_builder.info)
# Out:
# tfds.core.DatasetInfo(
#     name='cifar100',
#     version=1.3.1,
#     description='This dataset is just like the CIFAR-10, except it has 100 classes containing 600 images each. There are 500 training images and 100 testing images per class. The 100 classes in the CIFAR-100 are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs).',
#     urls=['https://www.cs.toronto.edu/~kriz/cifar.html'],
#     features=FeaturesDict({
#         'coarse_label': ClassLabel(shape=(), dtype=tf.int64, num_classes=20),
#         'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=100),
#     }),
#     total_num_examples=60000,
#     splits={
#         'test': 10000,
#         'train': 50000,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@TECHREPORT{Krizhevsky09learningmultiple,
#         author = {Alex Krizhevsky},
#         title = {Learning multiple layers of features from tiny images},
#         institution = {},
#         year = {2009}
#     }""",
#     redistribution_info=,
# )

# %% [markdown]
# From the above printed text, it also shows some useful information such as the number of training and testing samples, the key-names and so on.
#
# ## 1.2 - Examine the class labels of the dataset:

# %%
# Check out the labels:
print(cifar_builder.info.features["label"].names)

print('The number of classes are: {}'.format(len(cifar_builder.info.features["label"].names)))
# Out:
# ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']
# The number of classes are: 100

# %%
# Check out the coarse labels:
# print(cifar_builder.info.features["coarse_label"].names)

# print('The number of classes are: {}'.format(len(cifar_builder.info.features["coarse_label"].names)))

# %% [markdown]
# ## 1.3 - Define the Input Pipeline:
#
# As the dataset have been downloaded with the help of the package, this section will then define the input pipeline for the models to be trained. These are variables that will be used later on.

# %%
import math

# %%
# Define the Hyperparameters:
input_shape = [224, 224, 3]

# Batch size for ResNet50 is suitable with 64, but not for ResNet 152.
batch_size = 32
nb_epochs = 300

# %%
# Divide the dataset into training and validation sets:
train_set_cifar = cifar_builder.as_dataset(split = tfds.Split.TRAIN)
val_set_cifar = cifar_builder.as_dataset(split = tfds.Split.TEST)
# Out:
# WARNING:absl:Warning: Setting shuffle_files=True because split=TRAIN and shuffle_files=None. This behavior will be deprecated on 2019-08-06, at which point shuffle_files=False will be the default for all splits.

# %%
# Set the number of classes:
nb_classes = cifar_builder.info.features['label'].num_classes

# %%
# Define the number of images for training and validation:
nb_train_imgs = cifar_builder.info.splits['train'].num_examples
nb_valid_imgs = cifar_builder.info.splits['test'].num_examples

# %% [markdown]
# ## 1.4 - Check out the dataset instances:
#
# This should provide some additional details about the dataset, such as its dtype and shape.

# %%
print("The Training set instance: {}".format(train_set_cifar))
# Out:
# The Training set instance: <_OptionsDataset shapes: {coarse_label: (), image: (32, 32, 3), label: ()}, types: {coarse_label: tf.int64, image: tf.uint8, label: tf.int64}>

# %%
print("The Testing set instance: {}".format(val_set_cifar))
# Out:
# The Testing set instance: <_OptionsDataset shapes: {coarse_label: (), image: (32, 32, 3), label: ()}, types: {coarse_label: tf.int64, image: tf.uint8, label: tf.int64}>

# %% [markdown]
# ## 2 - Data Preprocessing:
#
# ## 2.1 - Shuffling the dataset:
#
# The notion behind shuffling the dataset before being used for training is so that the model is able to learn from majority of the data in the training set, where unshuffled, the training data can be in the format order of A-R while the testing set is S-Z, so during training the model only learns from what is available from A-R but will later perform badly in the unseen testing data of S-Z. Shuffling, as mentioned, allows the model to train in a more robust manner resulting in a better generalised model.

# %%
# Shuffle the Training Dataset: 10,000 times of reshuffling.
train_set_cifar = train_set_cifar.repeat(nb_epochs).shuffle(10000)

# %% [markdown]
# ## 2.2 - Set up the dataset for compatibility with Keras API (non-estimator) and Image Augmentation:
#
# It should be noted that Tensorflow-Dataset returns batches as feature dictionaries, which is expected by Estimators. Therefore, to train with Keras models, it is better to return the batch content as tuples. A user defined funtion will be needed to do this.

# %%
def _prepare_data_func(features, input_shape, augment=False):
    """ This builds a pre-processing function to resize the image into the expected dimensions and allows for an
        optional transformation of the images such as augmentations.
    Parameters:
        - features, is the input data.
        - input_shape, is the expected shape for model by resizing.
        - augment, is a Flag to apply random transformations to the input images.
    Returns:
        - returns Augmented images, Labels
    """
    
    # Convert the input images into tensors:
    input_shape = tf.convert_to_tensor(input_shape)
    
    # Convert TF-dataset feature dictionaries into Tuples:
    image = features['image']
    label = features['label']
    
    # Convert the image data type to "float32" and normalise the data to a range between "0 and 1":
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    # Data Image Augmentation:
    if augment:
        # Apply random horizontal flip::
        image = tf.image.random_flip_left_right(image)
        
        # Apply Brightness and Saturation changes:
        image = tf.image.random_brightness(image, max_delta = 0.1)
        image = tf.image.random_saturation(image, lower = 0.5, upper = 1.5)
        image = tf.clip_by_value(image, 0.0, 1.0) # this keeps the pixel values in check.
        
        # Apply random resizing and cropping back to expected image sizes:
        random_scale_factor = tf.random.uniform([1], minval = 1., maxval = 1.4, dtype = tf.float32)
        
        scaled_height = tf.cast(tf.cast(input_shape[0], tf.float32) * random_scale_factor, tf.int32)
        scaled_width = tf.cast(tf.cast(input_shape[1], tf.float32) * random_scale_factor, tf.int32)
        scaled_shape = tf.squeeze(tf.stack([scaled_height, scaled_width]))
        
        image = tf.image.resize(image, scaled_shape)
        image = tf.image.random_crop(image, input_shape)
    else:
        image = tf.image.resize(image, input_shape[:2])
        
    return image, label

# %% [markdown]
# #### Apply the function above on the training and validation set:
#
# NOTE: functools.partial example -> https://stackoverflow.com/questions/15331726/how-does-functools-partial-do-what-it-does

# %%
import functools

# %% [markdown]
# ##### For Training set:

# %%
# Set the function for the training data preparation:
prepare_data_func_for_trainSet = functools.partial(_prepare_data_func, input_shape = input_shape, augment = True)

# Map the function to the dataset:
train_set_cifar = train_set_cifar.map(prepare_data_func_for_trainSet, num_parallel_calls = tf.data.experimental.AUTOTUNE)

# Split the training set into batched samples:
train_set_cifar = train_set_cifar.batch(batch_size)

# Set to prefetch the data: improves the perforamnce.
# This allows later elements to be prepared while the current element is being processed. 
# This often improves latency and throughput, at the cost of using additional memory to store prefetched elements.
train_set_cifar= train_set_cifar.prefetch(1)

# %% [markdown]
# ##### For Validation set: no augment

# %%
# Set the function for the Validation data preparation:
prepare_data_func_for_ValidSet = functools.partial(_prepare_data_func, input_shape = input_shape, augment = False)

# Map the function to the dataset:
val_set_cifar = val_set_cifar.map(prepare_data_func_for_ValidSet, num_parallel_calls = tf.data.experimental.AUTOTUNE)

# Split the Validation set into batched samples:
val_set_cifar = val_set_cifar.batch(batch_size)

# Set to prefetch the data: improves the perforamnce.
# his allows later elements to be prepared while the current element is being processed. 
# This often improves latency and throughput, at the cost of using additional memory to store prefetched elements.
val_set_cifar = val_set_cifar.prefetch(1)

# %% [markdown]
# ## 2.3 - Set the "steps_per_epoch" for Training and Validation Set:
#
# From the previous code block, the dataset is compatible with Keras methods liike "model.fit()", but will also require the "steps_per_epoch" to be specified. This is the number of batches per epoch of the Dataset objects that has to be specified for the Keras method so that it can work properly together. This is done for the training batches ("steps_per_epoch") and validation batches ("validation_steps").

# %%
train_steps_per_epoch = math.ceil(nb_train_imgs / batch_size)

valid_steps_per_epoch = math.ceil(nb_valid_imgs / batch_size)

# %% [markdown]
# ### The data preparation "_prepare_data_func" function will be placed into a ".py" utily file, so that it can be reuse later on.
#
# ## 3 - ResNet Implementation with Keras:
#
# This section will dive into making a ResNet builder tool, where the goal is to be able to instantiate a range of deep ResNet model such as Resnet-18 to Resnet-101 and so on. The Keras Functional API will be used to simplify the process.
#
# ## 3.1 - Import the required libraries:

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Activation, Dense, Flatten, Conv2D, MaxPooling2D, 
                                     GlobalAveragePooling2D, AveragePooling2D, BatchNormalization, add)
import tensorflow.keras.regularizers as regulisers

# %% [markdown]
# ## 3.2 - Residual Blocks Implementations:
#
# For the purpose of building a ResNet model builder function that is capable of generating a network of different sizes, the implementation of ResNet therefore have to be modular as well. To do this, each of the components that make up the ResNet model will implemented separately/modular below.
#
# __Residual Blocks__ are composed of the following:
# - 1x Residual Branch; a 3x3 convolution on the input data, followed by batch normalisation and then a ReLU activation function.
# - 1x Shortcut Branch; it directly forwards the input without any modification, or that it can apply a 1x1 convolution to adapt the input volume where in the case it changes in the other branch.
# - 1x Merge Operation; consisting of an element-wise addition between the output results of the two branches.
#
# The following will then implement each of the Sub-modules of the ResNet model.
#
# ### 3.2.1 - (Subblock 1) Residual Branch:
#
# Wrap the convolution, batch normalisation and ReLU activation as a stack of layers into a single function. The function below allows for the addition of 3 stacked layers (conv_bn_Relu) with just a " x = _conv_bn_Relu(**params)(x) " code for the residual branch.
#
# This is also called the __residual path (GREEN)__ and can be seen in the previous notebook in Section 1.4.

# %%
def _res_conv(filters, kernel_size=3, padding='same', strides=1, use_relu=True, use_bias=False, name='conv_bn_Relu', 
              kernel_initialiser = 'he_normal', kernel_regulariser = regulisers.l2(1e-5)):
    """ This builds the Residual Branch, consisting of the Convolutions, batch norm and ReLU activation.
    Parameters:
        - filters, is the number of filters.
        - kernel_size, is the Kernel Size.
        - padding, is the convolution padding.
        - strides, is the convolution stride.
        - use_rele, is a Flag to apply the ReLU activation function at the end.
        - use_bias, is a Flag to use or not the bias in the Convolutional layer.
        - name, is the Name Suffix for the layers.
        - kernel_initialiser, is the Kernel initialisattion method name.
        - kernel_regulariser, is the kernel regulariser.
    Returns:
        - returns a Callable Layer Block.
    """
    def layer_func(x):
        # Convolution:
        conv = Conv2D(filters = filters,
                      kernel_size = kernel_size,
                      strides = strides,
                      padding = padding,
                      use_bias = use_bias,
                      kernel_initializer = kernel_initialiser,
                      kernel_regularizer = kernel_regulariser,
                      name = name + '_c'
                     )(x)
                
        # Batch Norm:
        residual_branch = BatchNormalization(axis = -1,
                                             name = name + '_bn'
                                            )(conv)
        
        # ReLU activation:
        if use_relu:
            residual_branch = Activation(activation = 'relu',
                                         name = name + '_r'
                                        )(residual_branch)
        return residual_branch
    
    return layer_func

# %% [markdown]
# ### 3.2.2 - (Subblock 2) Shortcut Branch:
#
# Simplifying the __shortcut operation__ can be done by coupling it with the __merge operation__. This "_merge_with_shortcut" function needs to receive parameters of both the input tensor and the results of the residual branch, so that it can compare the shapes of the tensor, checking it the dimensions were changed or not.
#
# If the dimensions were changed, a 1x1 convolution will be applied to resize the input tensor before merging. If unchanged, the input tensor will be left unaltered.
#
# As this function have both the residual and shortcut results, it can merge the results together.
#
# This is also called the __mapping path (BLUE)__ and can be seen in the previous notebook in Section 1.4.

# %%
def _merge_with_shortcut(kernel_initialiser = 'he_normal', kernel_regulariser = regulisers.l2(1e-5), name='block'):
    """ This builds the merging layer block for the input tensor and the residual branch output tensor.
    Parameters:
        - kernel_initialiser, is the Kernel initialisation method name.
        - kernel_regulariser, is the Kernel regulariser.
        - name, is the Name Suffix of this layer.
    Returns:
        - returns a Callable Layer Block.
    """
    def layer_func(x, x_residual):
        # Check if there are changes made to the residual branch output "x_residual": 
        # if changed, apply 1x1 convolutions.
        x_shape = tf.keras.backend.int_shape(x)
        x_residual_shape = tf.keras.backend.int_shape(x_residual)
        
        if (x_shape == x_residual_shape):
            shortcut = x
        else:
            strides = (
                        int(round(x_shape[1] / x_residual_shape[1])), # Vertical Stride.
                        int(round(x_shape[2] / x_residual_shape[2]))  # horizontal Stride.
                      )
            x_residual_chnls = x_residual_shape[3]
            
            shortcut = Conv2D(filters = x_residual_chnls,
                              kernel_size = (1, 1),
                              strides = strides,
                              padding = "valid",
                              kernel_initializer = kernel_initialiser,
                              kernel_regularizer = kernel_regulariser,
                              name = name + '_shortcut_c'
                             )(x)
            
        # Merge the shortcut and residual:
        merge = add( [shortcut, x_residual] )

        # Return the merged output:
        return merge
        
    return layer_func

# %% [markdown]
# ## 3.2.3 - Create a Complete Residual Block:
#
# The complete residual block will be formed by chaining the residual blocks:
# - _residual_block_basic(filters=64, strides=2)(x)
# - _residual_block_basic(filters=64, strides=1)(x)
# - where (x) is the previous layer.

# %%
def _residual_block_basic(filters, kernel_size=3, strides=1, use_bias=False, kernel_initialiser='he_normal', 
                          kernel_regulariser=regulisers.l2(1e-5), name='res_basic'):
    """ This builds the Basic Residual Layer Block.
    Parameters:
        - filters, is the number of filters.
        - kernel_size, is the kernel size.
        - strides, is the convolutional strides.
        - use_bias, is a Flag to use or not the bias in the convolution layer.
        - kernel_initialiser, is the kernel initialisation method name.
        - kernel_regulariser, is the kernel regulariser.
    Returns:
        - returns a Callable Layer Block.
    """
    def layer_func(x):
        # For the Residual Branch - the First Convolution block:
        x_conv1 = _res_conv(filters = filters,
                            kernel_size= kernel_size,
                            padding='same',
                            strides= strides,
                            use_relu=True,
                            use_bias= use_bias,
                            kernel_initialiser= kernel_initialiser,
                            kernel_regulariser= kernel_regulariser,
                            name = name + '_conv_bn_Relu1'
                           )(x)
        
        # For the Residual Branch - the Second Convolution block:
        x_residual = _res_conv(filters = filters,
                            kernel_size= kernel_size,
                            padding='same',
                            strides= 1,
                            use_relu= False,
                            use_bias= use_bias,
                            kernel_initialiser= kernel_initialiser,
                            kernel_regulariser= kernel_regulariser,
                            name = name + '_conv_bn_Relu2'
                           )(x_conv1)
        
        # For the Merging (Identity/shortcut) Branch:
        merge = _merge_with_shortcut(kernel_initialiser=kernel_initialiser,
                                     kernel_regulariser=kernel_regulariser,
                                     name = name)(x, x_residual)
        
        merge = Activation('relu')(merge)
        
        # Return the merged output:
        return merge
    
    return layer_func

# %% [markdown]
# ## 3.2.4 - Create a Secondary Complete Residual Block, Bottleneck Residual Block:
#
# Before estanblishing the final complete model, there is a secondary residual block that requires implementation. This was previously mentioned in the last notebook, it is where Geoffrey Hinton suggests a bottleneck residual block that combats the computationally complex basic residual blocks when the network becomes deeper. This is where the two 3x3 convolutions are replaced by one 3x3 convolutions that is surrounded by 1x1 ones.

# %%
def _residual_bottleneck_blocks(filters, kernel_size=3, strides=1, use_bias=False, 
                                kernel_initialiser='he_normal', kernel_regulariser=regulisers.l2(1e-5), name='res_bottleneck'):
    """ This builds the Bottlenecked Residual Blocks, for a ResNet model deeper than 34 layers.
    Parameters:
        - filters, is the number of filters.
        - kernel_size, is the kernel size.
        - strides, is the convolutional strides.
        - use_bias, is a Flag to use or not the bias in the convolution layer.
        - kernel_initialiser, is the kernel initialisation method name.
        - kernel_regulariser, is the kernel regulariser.
    Returns:
        - returns a Callable Layer Block.
    """
    def layer_func(x):
        # For the Bottleneck Residual Branch - the First (bottlenecked) Convolution block:
        x_bottleneck = _res_conv(filters = filters, 
                                 kernel_size= 1, 
                                 padding='valid', 
                                 strides= strides, 
                                 use_relu=True, 
                                 use_bias= use_bias, 
                                 kernel_initialiser= kernel_initialiser, 
                                 kernel_regulariser= kernel_regulariser, 
                                 name = name + '_conv_bn_Relu1'
                                )(x)
        
        # For the Residual Branch - the first (non-bottlenecked) Convolution block:
        x_conv = _res_conv(filters = filters, 
                           kernel_size= kernel_size, 
                           padding='same', 
                           strides= 1, 
                           use_relu=True, 
                           use_bias= use_bias, 
                           kernel_initialiser= kernel_initialiser, 
                           kernel_regulariser= kernel_regulariser, 
                           name = name + '_conv_bn_Relu2'
                          )(x_bottleneck)
        
        # For the Residual Branch - the Second (non-bottlenecked) Convolution block:
        x_residual = _res_conv(filters = filters * 4, 
                               kernel_size= 1, 
                               padding='valid', 
                               strides= 1, 
                               use_relu= False, 
                               use_bias= use_bias, 
                               kernel_initialiser= kernel_initialiser, 
                               kernel_regulariser= kernel_regulariser, 
                               name = name + '_conv_bn_Relu3'
                              )(x_conv)
        
        # For the Merging (Identity/shortcut) Branch:
        merge = _merge_with_shortcut(kernel_initialiser=kernel_initialiser,
                                     kernel_regulariser=kernel_regulariser,
                                     name = name)(x, x_residual)
        
        merge = Activation('relu')(merge)
        
        # Return the merged output:
        return merge
    
    return layer_func

# %% [markdown]
# ## 3.2.5 - Chaining the Blocks together to form Modular Networks:
#
# In the following diagram for the architecture of the ResNet model, it can be seen that there is a pattern. Where for every __B-block__, there is a residual block that consist of a strides = 2 for the purposes of reducing the spatial dimensionality, this is tthen followed by another B-block but with the strides = 1.
#
# To simplify the implementation for the purpose of Modular ResNet, the b-blocks will be wrapped together in its instantiation. The following function also makes it possible to easily chain up these macro-blocks together to form any deep (number of layers) ResNet Architecture desired.
#
# __NOTE__: (After training and printing the Predictions) to view this, uncomment the following libraries and run the code to display the image. This section colides with the PILLOW package used in section 6 below.

# %%
# from IPython.display import display, Image
# import matplotlib.pyplot as plt

# %%
# # ResNet Architecture: 
# display(Image(image_path + 'ResNet_b_block.PNG', width=350, unconfined=True))
# print('Image ref -> https://towardsdatascience.com/architecture-comparison-of-alexnet-vggnet-resnet-inception-densenet-beb8b116866d')

# %%
def _residual_macroblock(block_func, filters, repetitions =3, kernel_size=3, strides_1stBlock = 1, use_bias=False, 
                                kernel_initialiser='he_normal', kernel_regulariser=regulisers.l2(1e-5), name='res_macroblock'):
    """ This builds the a Layer block that is composed of a repetition of 'N' number of residual blocks.
    Parameters:
        - block_fun, is the Block Layer method.
        - repetitions, is the number of times the block func is repeated inside.
        - filters, is the number of filters.
        - kernel_size, is the kernel size.
        - strides_1st_block, is the convolutional strides for the 1st block.
        - use_bias, is a Flag to use or not the bias in the convolution layer.
        - kernel_initialiser, is the kernel initialisation method name.
        - kernel_regulariser, is the kernel regulariser.
    Returns:
        - returns a Callable Layer Block.
    """
    def layer_func(x):
        
        # Loop through the specified number of repetitions:
        for i in range(repetitions):
            block_name = "{}_{}".format(name, i)
            strides = strides_1stBlock if i == 0 else 1
            x = block_func(filters = filters,
                           kernel_size = kernel_size,
                           strides = strides,
                           use_bias = use_bias,
                           kernel_initialiser = kernel_initialiser,
                           kernel_regulariser = kernel_regulariser,
                           name = block_name)(x)
            
        # Return the output from this loop:
        return x
    
    return layer_func

# %% [markdown]
# ## 3.2.6 - Final Layers of the ResNet model:
#
# Previously, the code blocks were to implement the layers of residual blocks before the final layers. The final layers of the ResNet model here will be composed of the 3 layers preceeding the residual blocks, that is a 7x7 convolution and a max-pooling layer, and also the final fully connected layers that leads to the prediction output.
#
# The following function should call the defiend functions in the previous code blocks to form the final ResNet model (of any size).

# %%
def ResNet(input_shape, nb_classes = 1000, block_func = _residual_block_basic, repetitions = (2, 2, 2, 2),
           use_bias = False, kernel_initialiser = 'he_normal', kernel_regulariser = regulisers.l2(1e-5)):
    """ This builds the ResNet Model for the Classification task.
    Parameters:
        - input_shape, is the input data shape such as (224, 224, 3).
        - nb_classes, is the number of classes to be predicted.
        - block_func, is the Block Layer method to be used.
        - repetitions, is the List of repetitions for each macro-blocks the network should build/contain.
        - use_bias, is a Flag to use or not the bias in the convolution layer.
        - kernel_initialiser, is the kernel initialisation method name.
        - kernel_regulariser, is the kernel regulariser.
    Returns:
        - returns the ResNet model.
    """
    # ResNet's Input layer:
    inputs = Input(shape = input_shape)
    
    conv = _res_conv(filters = 64,
                    kernel_size= 7,
                    strides= 2,
                    use_relu= True,
                    use_bias= use_bias,
                    kernel_initialiser= kernel_initialiser,
                    kernel_regulariser= kernel_regulariser
                    )(inputs)
    
    maxpool = MaxPooling2D(pool_size= 3, 
                           strides= 2, 
                           padding='same')(conv)
    
    # Resnet's chain of Residual Blocks:
    filters = 64
    strides = 2
    res_block = maxpool
    
    for i, repet in enumerate(repetitions):
        # NOTE: no further input size reduction for the 1st block, as max-pooling was applied prior.
        block_strides = strides if i != 0 else 1
        macroblock_name = "block_{}".format(i)
        
        res_block = _residual_macroblock(block_func = block_func,
                                               filters = filters,
                                               repetitions = repet,
                                               strides_1stBlock = block_strides,
                                               use_bias = use_bias,
                                               kernel_initialiser = kernel_initialiser,
                                               kernel_regulariser = kernel_regulariser,
                                               name = macroblock_name
                                              )(res_block)
        
        # Limit the number of filters to 1024 as the maximum:
        filters = min(filters * 2, 1024)   
    
    # Resnet's Final/Output Layer:
    res_spatial_dimen = tf.keras.backend.int_shape(res_block)[1:3]
    
    avg_pool = AveragePooling2D(pool_size= res_spatial_dimen,
                                strides = 1
                               )(res_block)
    
    flatten = Flatten()(avg_pool)
    
    predictions = Dense(units = nb_classes,
                        activation = 'softmax',
                        kernel_initializer= kernel_initialiser
                       )(flatten)
    
    # Model (Keras API):
    model = Model(inputs = inputs, 
                  outputs = predictions)
    
    # Return the model configurations:
    return model

# %% [markdown]
# The above code block essentially allows for creation of a ResNet model that can be shallow or deep or very deep, with the use of the "repetitions" parameter.
#
# ## 4 - Instatiate the ResNet model:
#
# Here, it is possible to instantiate all of the classic ResNet models that were originally developed.

# %%
def ResNet18(input_shape, nb_classes = 1000, use_bias = True, kernel_initialiser = 'he_normal', kernel_regulariser = None):
    return ResNet(input_shape,
                  nb_classes= nb_classes,
                  block_func= _residual_block_basic,
                  repetitions = (2, 2, 2, 2),
                  use_bias = use_bias,
                  kernel_initialiser = kernel_initialiser,
                  kernel_regulariser = kernel_regulariser)

def ResNet34(input_shape, nb_classes = 1000, use_bias = True, kernel_initialiser = 'he_normal', kernel_regulariser = None):
    return ResNet(input_shape,
                  nb_classes= nb_classes,
                  block_func= _residual_block_basic,
                  repetitions = (3, 4, 6, 3),
                  use_bias = use_bias,
                  kernel_initialiser = kernel_initialiser,
                  kernel_regulariser = kernel_regulariser)


# For ResNet50, the basic residual blocks are replaced with bottleneck residual blocks instead:
def ResNet50(input_shape, nb_classes = 1000, use_bias = True, kernel_initialiser = 'he_normal', kernel_regulariser = None):
    return ResNet(input_shape,
                  nb_classes= nb_classes,
                  block_func= _residual_bottleneck_blocks,
                  repetitions = (3, 4, 6, 3),
                  use_bias = use_bias,
                  kernel_initialiser = kernel_initialiser,
                  kernel_regulariser = kernel_regulariser)

def ResNet101(input_shape, nb_classes = 1000, use_bias = True, kernel_initialiser = 'he_normal', kernel_regulariser = None):
    return ResNet(input_shape,
                  nb_classes= nb_classes,
                  block_func= _residual_bottleneck_blocks,
                  repetitions = (3, 4, 23, 3),
                  use_bias = use_bias,
                  kernel_initialiser = kernel_initialiser,
                  kernel_regulariser = kernel_regulariser)

def ResNet152(input_shape, nb_classes = 1000, use_bias = True, kernel_initialiser = 'he_normal', kernel_regulariser = None):
    return ResNet(input_shape,
                  nb_classes= nb_classes,
                  block_func= _residual_bottleneck_blocks,
                  repetitions = (3, 4, 36, 3),
                  use_bias = use_bias,
                  kernel_initialiser = kernel_initialiser,
                  kernel_regulariser = kernel_regulariser)

# %% [markdown]
# ## 4.1 - Instantiate ResNet-152 and demonstrate the model: Previously ResNet-50
#
# The ResNet-152 model is chosen to be used for next few sections. The input shape will be 224x224 pixels as per suggested by the creators of ResNet.

# %%
# Instantiate the model:
resnet152 = ResNet152(input_shape = input_shape,
                nb_classes = nb_classes)

# Model Summary:
resnet152.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_bn_Relu_c (Conv2D)         (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv_bn_Relu_bn (BatchNormaliza (None, 112, 112, 64) 256         conv_bn_Relu_c[0][0]
# __________________________________________________________________________________________________
# conv_bn_Relu_r (Activation)     (None, 112, 112, 64) 0           conv_bn_Relu_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv_bn_Relu_r[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu1_c (Conv (None, 56, 56, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu1_bn (Bat (None, 56, 56, 64)   256         block_0_0_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu1_r (Acti (None, 56, 56, 64)   0           block_0_0_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu2_c (Conv (None, 56, 56, 64)   36928       block_0_0_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu2_bn (Bat (None, 56, 56, 64)   256         block_0_0_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu2_r (Acti (None, 56, 56, 64)   0           block_0_0_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu3_c (Conv (None, 56, 56, 256)  16640       block_0_0_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_0_0_shortcut_c (Conv2D)   (None, 56, 56, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# block_0_0_conv_bn_Relu3_bn (Bat (None, 56, 56, 256)  1024        block_0_0_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 256)  0           block_0_0_shortcut_c[0][0]
#                                                                  block_0_0_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 56, 56, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu1_c (Conv (None, 56, 56, 64)   16448       activation[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu1_bn (Bat (None, 56, 56, 64)   256         block_0_1_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu1_r (Acti (None, 56, 56, 64)   0           block_0_1_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu2_c (Conv (None, 56, 56, 64)   36928       block_0_1_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu2_bn (Bat (None, 56, 56, 64)   256         block_0_1_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu2_r (Acti (None, 56, 56, 64)   0           block_0_1_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu3_c (Conv (None, 56, 56, 256)  16640       block_0_1_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_0_1_conv_bn_Relu3_bn (Bat (None, 56, 56, 256)  1024        block_0_1_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           activation[0][0]
#                                                                  block_0_1_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu1_c (Conv (None, 56, 56, 64)   16448       activation_1[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu1_bn (Bat (None, 56, 56, 64)   256         block_0_2_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu1_r (Acti (None, 56, 56, 64)   0           block_0_2_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu2_c (Conv (None, 56, 56, 64)   36928       block_0_2_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu2_bn (Bat (None, 56, 56, 64)   256         block_0_2_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu2_r (Acti (None, 56, 56, 64)   0           block_0_2_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu3_c (Conv (None, 56, 56, 256)  16640       block_0_2_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_0_2_conv_bn_Relu3_bn (Bat (None, 56, 56, 256)  1024        block_0_2_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           activation_1[0][0]
#                                                                  block_0_2_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu1_c (Conv (None, 28, 28, 128)  32896       activation_2[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu1_bn (Bat (None, 28, 28, 128)  512         block_1_0_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu1_r (Acti (None, 28, 28, 128)  0           block_1_0_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu2_c (Conv (None, 28, 28, 128)  147584      block_1_0_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu2_bn (Bat (None, 28, 28, 128)  512         block_1_0_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu2_r (Acti (None, 28, 28, 128)  0           block_1_0_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu3_c (Conv (None, 28, 28, 512)  66048       block_1_0_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_1_0_shortcut_c (Conv2D)   (None, 28, 28, 512)  131584      activation_2[0][0]
# __________________________________________________________________________________________________
# block_1_0_conv_bn_Relu3_bn (Bat (None, 28, 28, 512)  2048        block_1_0_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 512)  0           block_1_0_shortcut_c[0][0]
#                                                                  block_1_0_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu1_c (Conv (None, 28, 28, 128)  65664       activation_3[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu1_bn (Bat (None, 28, 28, 128)  512         block_1_1_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu1_r (Acti (None, 28, 28, 128)  0           block_1_1_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu2_c (Conv (None, 28, 28, 128)  147584      block_1_1_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu2_bn (Bat (None, 28, 28, 128)  512         block_1_1_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu2_r (Acti (None, 28, 28, 128)  0           block_1_1_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu3_c (Conv (None, 28, 28, 512)  66048       block_1_1_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_1_1_conv_bn_Relu3_bn (Bat (None, 28, 28, 512)  2048        block_1_1_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           activation_3[0][0]
#                                                                  block_1_1_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu1_c (Conv (None, 28, 28, 128)  65664       activation_4[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu1_bn (Bat (None, 28, 28, 128)  512         block_1_2_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu1_r (Acti (None, 28, 28, 128)  0           block_1_2_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu2_c (Conv (None, 28, 28, 128)  147584      block_1_2_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu2_bn (Bat (None, 28, 28, 128)  512         block_1_2_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu2_r (Acti (None, 28, 28, 128)  0           block_1_2_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu3_c (Conv (None, 28, 28, 512)  66048       block_1_2_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_1_2_conv_bn_Relu3_bn (Bat (None, 28, 28, 512)  2048        block_1_2_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           activation_4[0][0]
#                                                                  block_1_2_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu1_c (Conv (None, 28, 28, 128)  65664       activation_5[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu1_bn (Bat (None, 28, 28, 128)  512         block_1_3_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu1_r (Acti (None, 28, 28, 128)  0           block_1_3_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu2_c (Conv (None, 28, 28, 128)  147584      block_1_3_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu2_bn (Bat (None, 28, 28, 128)  512         block_1_3_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu2_r (Acti (None, 28, 28, 128)  0           block_1_3_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu3_c (Conv (None, 28, 28, 512)  66048       block_1_3_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_1_3_conv_bn_Relu3_bn (Bat (None, 28, 28, 512)  2048        block_1_3_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           activation_5[0][0]
#                                                                  block_1_3_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  131328      activation_6[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_0_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_0_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_0_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_0_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_0_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_0_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_0_shortcut_c (Conv2D)   (None, 14, 14, 1024) 525312      activation_6[0][0]
# __________________________________________________________________________________________________
# block_2_0_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_0_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 1024) 0           block_2_0_shortcut_c[0][0]
#                                                                  block_2_0_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_7[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_1_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_1_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_1_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_1_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_1_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_1_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_1_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_1_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           activation_7[0][0]
#                                                                  block_2_1_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_8[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_2_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_2_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_2_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_2_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_2_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_2_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_2_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_2_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           activation_8[0][0]
#                                                                  block_2_2_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_9[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_3_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_3_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_3_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_3_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_3_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_3_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_3_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_3_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           activation_9[0][0]
#                                                                  block_2_3_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_10[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_4_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_4_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_4_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_4_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_4_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_4_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_4_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_4_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           activation_10[0][0]
#                                                                  block_2_4_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_11[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_5_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_5_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_5_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_5_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_5_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_5_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_5_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_5_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           activation_11[0][0]
#                                                                  block_2_5_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_12[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_6_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_6_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_6_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_6_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_6_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_6_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_6_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_6_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           activation_12[0][0]
#                                                                  block_2_6_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_13[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_7_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_7_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_7_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_7_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_7_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_7_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_7_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_7_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 14, 14, 1024) 0           activation_13[0][0]
#                                                                  block_2_7_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 1024) 0           add_14[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_14[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_8_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_8_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_8_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_8_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_8_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_8_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_8_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_8_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 14, 14, 1024) 0           activation_14[0][0]
#                                                                  block_2_8_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 14, 14, 1024) 0           add_15[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu1_c (Conv (None, 14, 14, 256)  262400      activation_15[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu1_bn (Bat (None, 14, 14, 256)  1024        block_2_9_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu1_r (Acti (None, 14, 14, 256)  0           block_2_9_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu2_c (Conv (None, 14, 14, 256)  590080      block_2_9_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu2_bn (Bat (None, 14, 14, 256)  1024        block_2_9_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu2_r (Acti (None, 14, 14, 256)  0           block_2_9_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu3_c (Conv (None, 14, 14, 1024) 263168      block_2_9_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_9_conv_bn_Relu3_bn (Bat (None, 14, 14, 1024) 4096        block_2_9_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 14, 14, 1024) 0           activation_15[0][0]
#                                                                  block_2_9_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 14, 14, 1024) 0           add_16[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_16[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_10_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_10_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_10_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_10_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_10_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_10_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_10_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_10_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 14, 14, 1024) 0           activation_16[0][0]
#                                                                  block_2_10_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 14, 14, 1024) 0           add_17[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_17[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_11_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_11_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_11_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_11_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_11_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_11_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_11_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_11_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 14, 14, 1024) 0           activation_17[0][0]
#                                                                  block_2_11_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 1024) 0           add_18[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_18[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_12_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_12_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_12_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_12_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_12_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_12_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_12_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_12_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 14, 14, 1024) 0           activation_18[0][0]
#                                                                  block_2_12_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 1024) 0           add_19[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_19[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_13_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_13_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_13_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_13_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_13_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_13_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_13_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_13_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 14, 14, 1024) 0           activation_19[0][0]
#                                                                  block_2_13_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 1024) 0           add_20[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_20[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_14_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_14_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_14_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_14_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_14_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_14_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_14_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_14_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 14, 14, 1024) 0           activation_20[0][0]
#                                                                  block_2_14_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 1024) 0           add_21[0][0]
# __________________________________________________________________________________________________
# block_2_15_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_21[0][0]
# __________________________________________________________________________________________________
# block_2_15_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_15_conv_bn_Relu1_c[0][0]
# ...
#                                                                  block_2_31_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 1024) 0           add_38[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_38[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_32_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_32_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_32_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_32_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_32_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_32_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_32_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_32_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 14, 14, 1024) 0           activation_38[0][0]
#                                                                  block_2_32_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 1024) 0           add_39[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_39[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_33_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_33_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_33_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_33_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_33_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_33_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_33_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_33_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 14, 14, 1024) 0           activation_39[0][0]
#                                                                  block_2_33_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_40[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_40[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_34_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_34_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_34_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_34_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_34_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_34_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_34_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_34_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 14, 14, 1024) 0           activation_40[0][0]
#                                                                  block_2_34_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 1024) 0           add_41[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu1_c (Con (None, 14, 14, 256)  262400      activation_41[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu1_bn (Ba (None, 14, 14, 256)  1024        block_2_35_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu1_r (Act (None, 14, 14, 256)  0           block_2_35_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu2_c (Con (None, 14, 14, 256)  590080      block_2_35_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu2_bn (Ba (None, 14, 14, 256)  1024        block_2_35_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu2_r (Act (None, 14, 14, 256)  0           block_2_35_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu3_c (Con (None, 14, 14, 1024) 263168      block_2_35_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_2_35_conv_bn_Relu3_bn (Ba (None, 14, 14, 1024) 4096        block_2_35_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 14, 14, 1024) 0           activation_41[0][0]
#                                                                  block_2_35_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 1024) 0           add_42[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu1_c (Conv (None, 7, 7, 512)    524800      activation_42[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu1_bn (Bat (None, 7, 7, 512)    2048        block_3_0_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu1_r (Acti (None, 7, 7, 512)    0           block_3_0_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu2_c (Conv (None, 7, 7, 512)    2359808     block_3_0_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu2_bn (Bat (None, 7, 7, 512)    2048        block_3_0_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu2_r (Acti (None, 7, 7, 512)    0           block_3_0_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu3_c (Conv (None, 7, 7, 2048)   1050624     block_3_0_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_3_0_shortcut_c (Conv2D)   (None, 7, 7, 2048)   2099200     activation_42[0][0]
# __________________________________________________________________________________________________
# block_3_0_conv_bn_Relu3_bn (Bat (None, 7, 7, 2048)   8192        block_3_0_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 7, 7, 2048)   0           block_3_0_shortcut_c[0][0]
#                                                                  block_3_0_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_43[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu1_c (Conv (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu1_bn (Bat (None, 7, 7, 512)    2048        block_3_1_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu1_r (Acti (None, 7, 7, 512)    0           block_3_1_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu2_c (Conv (None, 7, 7, 512)    2359808     block_3_1_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu2_bn (Bat (None, 7, 7, 512)    2048        block_3_1_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu2_r (Acti (None, 7, 7, 512)    0           block_3_1_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu3_c (Conv (None, 7, 7, 2048)   1050624     block_3_1_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_3_1_conv_bn_Relu3_bn (Bat (None, 7, 7, 2048)   8192        block_3_1_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 7, 7, 2048)   0           activation_43[0][0]
#                                                                  block_3_1_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 2048)   0           add_44[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu1_c (Conv (None, 7, 7, 512)    1049088     activation_44[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu1_bn (Bat (None, 7, 7, 512)    2048        block_3_2_conv_bn_Relu1_c[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu1_r (Acti (None, 7, 7, 512)    0           block_3_2_conv_bn_Relu1_bn[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu2_c (Conv (None, 7, 7, 512)    2359808     block_3_2_conv_bn_Relu1_r[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu2_bn (Bat (None, 7, 7, 512)    2048        block_3_2_conv_bn_Relu2_c[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu2_r (Acti (None, 7, 7, 512)    0           block_3_2_conv_bn_Relu2_bn[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu3_c (Conv (None, 7, 7, 2048)   1050624     block_3_2_conv_bn_Relu2_r[0][0]
# __________________________________________________________________________________________________
# block_3_2_conv_bn_Relu3_bn (Bat (None, 7, 7, 2048)   8192        block_3_2_conv_bn_Relu3_c[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 7, 7, 2048)   0           activation_44[0][0]
#                                                                  block_3_2_conv_bn_Relu3_bn[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 2048)   0           add_45[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 2048)   0           activation_45[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          204900      flatten[0][0]
# ==================================================================================================
# Total params: 57,431,012
# Trainable params: 57,293,412
# Non-trainable params: 137,600
# __________________________________________________________________________________________________

# %% [markdown]
# ## 5 - Perform Classification with ResNet-152 Model:
#
# Apply the ResNet-50 model to the CIFAR-100 dataset for classification task.
#
# ## 5.1 - Preparation for training:
#
# Instantiate the model optimiser and the required callbacks for visualisation of the model performance. This also saves the model's progress and results.
#
# As mentioned earlier, the ImageNet experiments contains the Top-5 accuracy metrics and this will be added in the following code block. TensorFlow and Keras already provides multiple pre-defined losses and metrics to be implemented.

# %%
# Define the model optimiser:
optimiser = tf.keras.optimizers.Adam()

# Define the accuracy metric:
accuracy_metric = tf.metrics.SparseCategoricalAccuracy(name = 'acc')

# Define the top-5 accuracy metric: a.k.a Top-K
top5_acc_metric = tf.metrics.SparseTopKCategoricalAccuracy(k = 5,
                                                           name = 'top5_acc')

# %% [markdown]
# ### Compile the model:

# %%
resnet152.compile(optimizer = optimiser,
                 loss = 'sparse_categorical_crossentropy',
                 metrics = [accuracy_metric, top5_acc_metric]
                )

# %% [markdown]
# ### Callbacks:
#
# This section will implement a custom Callback Class. It defines an interface that is composed of several methods, that will be called by Keras during the training process. The intervals for calling Keras are "before each epoch", "before each batch iteration", "after each batch iteration" and so on.
#
# NOTE: to ensure that the logs are concise, a "log_frequency" variable will be used to print out the results at different intervals during the training process.

# %%
import collections

# %%
# Setting some variables to format the logs:
log_begin_red, log_begin_blue, log_begin_green = '\033[91m', '\033[94m', '\033[92m'
log_begin_bold, log_begin_underline = '\033[1m', '\033[4m'
log_end_format = '\033[0m'

# %%
class Simplified_LogCallback(tf.keras.callbacks.Callback):
    """ This builds the Keras Callbacks for a more simpler and concise console logs."""
    def __init__(self, metrics_dict, nb_epochs='?', log_frequency=1, 
                 metric_string_template='\033[1m[[name]]\033[0m = \033[94m{[[value]]:5.3f}\033[0m'):
        """ This is the Initialisation of the Callback.
        Parameters:
            - metrics_dict, is the Dict containing the mappings for metrics names(or keys), 
                    e.g. {"accuracy": "acc", "val. accuracy": "val_acc"}.
            - nb_epochs, is the number of training epochs.
            - log_frequency, is the frequency that the logs will be printed in epochs.
            - metric_string_template, is an optional Sttring template to print each of the metric.
        """
        # Initialise and Inherit "tf.keras.callbacks.Callback":
        super().__init__()
        
        self.metrics_dict = collections.OrderedDict(metrics_dict)
        self.nb_epochs = nb_epochs
        self.log_frequency = log_frequency
        
        # Build the format for printing out the metrics:
        # e.g. "Epoch 0/9: loss = 1.00; val-loss = 2.00"
        log_string_template = 'Epoch {0:2}/{1}: '
        separator = '; '
        
        i = 2
        for metric_name in self.metrics_dict:
            templ = metric_string_template.replace('[[name]]', metric_name).replace('[[value]]', str(i))
            log_string_template += templ + separator
            i += 1
            
        # Remove the "; " (separator) after the last element:
        log_string_template = log_string_template[:-len(separator)]
        self.log_string_template = log_string_template
        
    def on_train_begin(self, logs=None):
        print("Training: {}start{}".format(log_begin_red, log_end_format))
        
    def on_train_end(self, logs=None):
        print("Training: {}end{}".format(log_begin_green, log_end_format))
        
    def on_epoch_end(self, epoch, logs= {}):
        if (epoch - 1) % self.log_frequency == 0 or epoch == self.nb_epochs:
            values = [logs[self.metrics_dict[metric_name]] for metric_name in self.metrics_dict]
            print(self.log_string_template.format(epoch, self.nb_epochs, *values))

# %% [markdown]
# The callback "Simplified_LogCallback" function will be placed into a ".py" utily file, so that it can be reuse later on.
#
# ### Instantiate and prepare the callbacks needed and applying it to the training process:

# %%
# Callback to log metrics at the end of each epoch: this saves space compared to Verbose = 1.
metrics_to_print = collections.OrderedDict( [("loss", "loss"), 
                                            ("v-loss", "val_loss"),
                                            ("acc", "acc"), 
                                            ("v-acc", "val_acc"),
                                            ("top5-acc", "top5_acc"), 
                                            ("v-top5-acc", "val_top5_acc")] 
                                          )

callback_simple_log = Simplified_LogCallback(metrics_dict = metrics_to_print, 
                                             nb_epochs = nb_epochs, 
                                             log_frequency= 2)

# %%
# Set up the working directory for the model:
model_folderName = './models'
model_path = os.path.abspath(model_folderName)

# %%
# Define the model directtory:
# model_dir = './models/ResNet50_run1'
# model_dir = '.\models\ResNet50_run1'
model_dir = '.\models\ResNet50_run2'

# Define the Callbacks:
callbacks = [
    
    # Callback to interrupt the training if the validation loss/metric stops imrpoving for some amount of epochs:
    tf.keras.callbacks.EarlyStopping(monitor ='val_acc',
                                    patience =8,
                                    restore_best_weights = True
                                    ),
    
    # Callback to log the graph, Losses and Metrics into TensorBoard:
    tf.keras.callbacks.TensorBoard(log_dir = model_dir,
                                    histogram_freq = 0,
                                    write_graph = True
                                  ),
    
    # Callback to save the model: at every 5 epochs and specifies the poch and val-loss in the filename.
    tf.keras.callbacks.ModelCheckpoint(
        os.path.join(model_dir, 'weights-epoch{epoch:02}-loss{val_loss:.2f}.h5'), period = 5
    ), 
    
    # Log the Callbacks:
    callback_simple_log   
]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.

# %% [markdown]
# ## 5.2 - Training the ResNet-152 model:

# %%
# running time calculation
start = timeit.default_timer()

# %%
history_resnet152 = resnet152.fit(train_set_cifar,
                      epochs = nb_epochs,
                      steps_per_epoch= train_steps_per_epoch,
                      validation_data= (val_set_cifar),
                      validation_steps= valid_steps_per_epoch,
                      verbose=0,
                      callbacks= callbacks)
# Out:
# Training: start
# Epoch  1/300: loss = 3.511; v-loss = 7.130; acc = 0.163; v-acc = 0.091; top5-acc = 0.422; v-top5-acc = 0.273
# Epoch  3/300: loss = 2.611; v-loss = 2.439; acc = 0.330; v-acc = 0.365; top5-acc = 0.649; v-top5-acc = 0.684
# Epoch  5/300: loss = 2.010; v-loss = 1.982; acc = 0.462; v-acc = 0.473; top5-acc = 0.770; v-top5-acc = 0.782
# Epoch  7/300: loss = 1.647; v-loss = 1.579; acc = 0.545; v-acc = 0.558; top5-acc = 0.835; v-top5-acc = 0.846
# Epoch  9/300: loss = 1.379; v-loss = 1.513; acc = 0.609; v-acc = 0.579; top5-acc = 0.877; v-top5-acc = 0.855
# Epoch 11/300: loss = 1.189; v-loss = 1.384; acc = 0.657; v-acc = 0.619; top5-acc = 0.905; v-top5-acc = 0.877
# Epoch 13/300: loss = 1.023; v-loss = 1.295; acc = 0.700; v-acc = 0.646; top5-acc = 0.928; v-top5-acc = 0.892
# Epoch 15/300: loss = 0.883; v-loss = 1.333; acc = 0.737; v-acc = 0.652; top5-acc = 0.944; v-top5-acc = 0.895
# Epoch 17/300: loss = 0.770; v-loss = 1.751; acc = 0.766; v-acc = 0.618; top5-acc = 0.956; v-top5-acc = 0.872
# Epoch 19/300: loss = 0.661; v-loss = 1.356; acc = 0.799; v-acc = 0.656; top5-acc = 0.967; v-top5-acc = 0.896
# Epoch 21/300: loss = 0.573; v-loss = 1.351; acc = 0.822; v-acc = 0.670; top5-acc = 0.976; v-top5-acc = 0.896
# Epoch 23/300: loss = 0.498; v-loss = 1.367; acc = 0.843; v-acc = 0.674; top5-acc = 0.981; v-top5-acc = 0.900
# Epoch 25/300: loss = 0.435; v-loss = 1.330; acc = 0.862; v-acc = 0.687; top5-acc = 0.986; v-top5-acc = 0.902
# Epoch 27/300: loss = 0.388; v-loss = 1.418; acc = 0.877; v-acc = 0.675; top5-acc = 0.989; v-top5-acc = 0.899
# Epoch 29/300: loss = 0.348; v-loss = 1.574; acc = 0.887; v-acc = 0.657; top5-acc = 0.991; v-top5-acc = 0.891
# Epoch 31/300: loss = 0.312; v-loss = 1.497; acc = 0.898; v-acc = 0.673; top5-acc = 0.993; v-top5-acc = 0.902
# Epoch 33/300: loss = 0.285; v-loss = 1.613; acc = 0.908; v-acc = 0.673; top5-acc = 0.994; v-top5-acc = 0.896
# Training: end

# %%
# Stop the timer:
stop = timeit.default_timer()
print('Time: {} Minutes'.format(round((stop - start)/60, 2)))
print('Time: {} hours'.format(round((stop - start)/3600, 2)))
# Out:
# Time: 362.45 Minutes
# Time: 6.04 hours

# %% [markdown]
# ### Obseration:
#
# As it can be seen from the printed logs above, the model was able to achieve an accuracy score of ~94.5% coupled with a validation accuracy of ~65%. Further, it was able to obtain a validation top-5 accuracy of ~88.3%. From the process of training, it can be seen that the model took about 4.12 hours to reach this point on a decent machine, however, the time taken is fairly long. This is one of the reason transfer learning is more practical for development.
#
# ## 5.3 - Plot the Model's Performance:
#
# NOTE: the "history" object returned from the "model.fit()" method also provides data for plotting the training metrics. The following till plot these metrics.
#
# These can also be found in TensorBoard with the input in terminal: "tensorboard --logdir ./models"

# %%
fig, ax = plt.subplots(3, 2, figsize=(15, 10), sharex='col') # add parameter `sharey='row'` for a more direct comparison
ax[0, 0].set_title("loss")
ax[0, 1].set_title("val-loss")
ax[1, 0].set_title("acc")
ax[1, 1].set_title("val-acc")
ax[2, 0].set_title("top5-acc")
ax[2, 1].set_title("val-top5-acc")

ax[0, 0].plot(history_resnet152.history['loss'])
ax[0, 1].plot(history_resnet152.history['val_loss'])
ax[1, 0].plot(history_resnet152.history['acc'])
ax[1, 1].plot(history_resnet152.history['val_acc'])
ax[2, 0].plot(history_resnet152.history['top5_acc'])
ax[2, 1].plot(history_resnet152.history['val_top5_acc'])

# %%
# Get the best performing scores:
best_val_accuracy = max(history_resnet152.history['val_acc']) * 100
best_val_top5accuracy = max(history_resnet152.history['val_top5_acc']) * 100

# Print out the results:
print("Best Validation Accuracy: {:2.2f}%".format(best_val_accuracy))
print("Best Validation Top 5 Accuracy: {:2.2f}%".format(best_val_top5accuracy))
# Out:
# Best Validation Accuracy: 68.67%
# Best Validation Top 5 Accuracy: 90.25%

# %% [markdown]
# ### Observation:
#
# Based on the Validation Accuracy above, the model guesses the exact class out of 200 only ~35% (100% - 66.26%) most of the time, meaning that it is not very capable. It should be noted however, that this dataset is considered to be challenging and that it does not present with enough training samples for each of the classes for the model to learning well enough. Therefore, some further considerations for improving the model is needed.
#
# ## 6 - Model Prediction: Test the trainied model on Unseen Data (Testing Set).
#
# The trained model can now be used on unseen images from the testing dataset. To do this, a few utility functions will be required to load the __testing images as numpy arrays__, to obtain the Top-5 predictions and its corresponding labels from the model's output guesses. Lastly, it is to plot these results.

# %%
# Import the required libraries:
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %% [markdown]
# ## 6.1 - Utility Functions:

# %%
def load_image(image_path, size):
    """ This builds an Image Loader where it converts the images into Numpy Arrays.
    Parameters:
        - image_path, is the directory pathway to the images.
        - size, is the target size of the images.
    Returns:
        - returns an Image Array, that is normalised between 0 and 1.
    """
    image = img_to_array(load_img(image_path, target_size = size)) / 255.
    return image

def process_predictions(class_probabilities, class_readable_labels, k=5):
    """ This builds a Batch of predictions from the Estimator.
    Parameters:
        - class_probabilities, is the prediction results that is returned by the Keras Classifier for a batch of data.
        - class_readable_labels, is the List of readable class labels that is used for display.
        - k, is the number of top predictions in/for consideration.
    Returns:
        - returns the readable labels and probabilities for the predicted classes.
    """
    # Define an empty array for the Labels and Probabilities:
    topk_labels = []
    topk_probabilities = []
    top5_probabilities = []
    
    # Loop through the (sorted for top 5) predictions:
    for i in range(len(class_probabilities)):
        
        # Grab the top-k predictions: "-k" takes the first 5 results.
        topk_classes = sorted(np.argpartition(class_probabilities[i], -k)[-k:])
        
        # Get the corresponding labels and predictions:
        topk_labels.append( [class_readable_labels[predicted] for predicted in topk_classes] )
        
        # Update the List while,
        # Convert Eager Tensor to Numpy Array: for compatibility of loop iterations.
        class_probabilities = np.array(class_probabilities)
        topk_probabilities.append(class_probabilities[i][topk_classes])

    # Return the labels and its probabilities:
    return topk_labels, topk_probabilities

def display_predicitons(images, topk_labels, topk_probabilities):
    """ This build a Plotting function to display the batch of predictions.
    Parameters:
        - iamges, is the Batch of input images.
        - topk_labels, is the String labels of the predicted classes.
        - topk_probabilities, is the probabilities for each of the classes.
    """
    # Define the Plot size with number of images:
    nb_images = len(images)
    nb_images_sqrt = np.sqrt(nb_images)
    plot_cols = plot_rows = int(np.ceil(nb_images_sqrt))
    
    # Plotting:
    figure = plt.figure(figsize = (13, 10))
    grid_spec = gridspec.GridSpec(plot_cols, plot_rows)
    
    for i in range(nb_images):
        img, pred_labels, pred_probs = images[i], topk_labels[i], topk_probabilities[i]
        
        # Resize the labels for better fit with plots:
        pred_labels = [label.split(',')[0][:20] for label in pred_labels]
        
        # Customise layout for multiple Axes in a grid-like pattern within a figure:
        grid_spec_idx = gridspec.GridSpecFromSubplotSpec(nrows = 3,
                                                        ncols = 1,
                                                        subplot_spec = grid_spec[i],
                                                        hspace= 0.1)
        
        # Plot the images itself:
        ax_img = figure.add_subplot(grid_spec_idx[:2])
        ax_img.axis('off')
        ax_img.imshow(img)
        ax_img.autoscale(tight = True)
        
        # Plot the bar chart for each of the predicitons:
        ax_pred = figure.add_subplot(grid_spec_idx[2])
        ax_pred.spines['top'].set_visible(False)
        ax_pred.spines['right'].set_visible(False)
        ax_pred.spines['bottom'].set_visible(False)
        ax_pred.spines['left'].set_visible(False)
        
        y_pos = np.arange(len(pred_labels))
        
        ax_pred.barh(y_pos, pred_probs, align = 'center')
        ax_pred.set_yticks(y_pos)
        ax_pred.set_yticklabels(pred_labels)
        ax_pred.invert_yaxis()
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### The above functions will be placed into a ".py" utily file, so that it can be reuse later on.
#
# ## 6.2 - Plot the Predictions:
#
# These images are taken from the web randomly.
#
# ### 6.2.1 - Load the images in:

# %%
# Locate the folder of images:
testing_filenames = glob.glob(os.path.join('Testing Images from Web', '*'))

# testing_filenames = glob.glob(os.path.join('res', '*'))

# Load in the images:
testing_imgs = np.asarray( [load_image(file, size = input_shape[:2]) for file in testing_filenames] )

# Checkout the image shape:
print("Testing Images: {}".format(testing_imgs.shape))
# Out:
# Testing Images: (15, 224, 224, 3)

# %% [markdown]
# ## 6.2.2 - Plot:
#
# Use the model to predict on the "image per image" or "batch per batch",  and display the results of its predictions.
#
# NOTE: The model was trainied on CIFAR image data where these images are originally 32x32 pixels, then these were scaled up to 224x224 pixels as suggest by ResNet creators for training. This means that the resulting imaages had important artifacts or low quality features.
#
# To test the model on images of the same quality, the testing images will be resized to 32x32 pixel and then followed by another resizing to an expected input size of 224x224 pixels.

# %%
# Define the batch of images:
img_batch = testing_imgs[:16]

# Perform the testing image resize:
cifar_original_imgSize = cifar_builder.info.features['image'].shape[:2]

# sized to 32x32 pixels.
image_batch_lowQuality = tf.image.resize(images = img_batch,
                                         size = cifar_original_imgSize)
# sized to 224x224 pixels.
image_batch_lowQuality = tf.image.resize(images = image_batch_lowQuality,
                                         size = input_shape[:2])

# Predictions:
predictions = resnet152.predict_on_batch(image_batch_lowQuality)
print("predicted class probabilities: {}".format(predictions.shape))

# Plot: using the utility funcs.
class_readable_labels = cifar_builder.info.features['label'].names
top5_labels, top5_probs = process_predictions(predictions, class_readable_labels)

display_predicitons(images = img_batch,
                    topk_labels = top5_labels,
                    topk_probabilities = top5_probs)
# Out:
# predicted class probabilities: (15, 100)

# %% [markdown]
# ### Conclusion:
#
# From the results above, it can be seen that the model does output some confusing predictions. For example, it confused a butterfly for a beetle, or the car to be a tank and so on. It does however, also gotten some predictions correct, where this can be seen for the man and woman, cloud and mountain. This could be due to the fact that the dataset is too small to learn well enough, or that the model architecture will require some tweaking or trying a deeper ResNet model.
#
# Additionally, by adding more testing images that aligns with the 100 classes may show a slight increase in correct predictions.
#
# ## 7 - Extension, Try using different testing images:
#
# The idea here, is to find more images that are aligned with the labels from the dataset.
#
# ## 7.1 - Load in the data:

# %%
# Locate the folder of images:
testing_filenames = glob.glob(os.path.join('Testing Images from Web 2', '*'))

# testing_filenames = glob.glob(os.path.join('res', '*'))

# Load in the images:
testing_imgs = np.asarray( [load_image(file, size = input_shape[:2]) for file in testing_filenames] )

# Checkout the image shape:
print("Testing Images: {}".format(testing_imgs.shape))
# Out:
# Testing Images: (16, 224, 224, 3)

# %% [markdown]
# ## 7.2 - Plot:

# %%
# Define the batch of images:
img_batch = testing_imgs[:16]

# Perform the testing image resize:
cifar_original_imgSize = cifar_builder.info.features['image'].shape[:2]

# sized to 32x32 pixels.
image_batch_lowQuality = tf.image.resize(images = img_batch,
                                         size = cifar_original_imgSize)
# sized to 224x224 pixels.
image_batch_lowQuality = tf.image.resize(images = image_batch_lowQuality,
                                         size = input_shape[:2])

# Predictions:
predictions = resnet152.predict_on_batch(image_batch_lowQuality)
print("predicted class probabilities: {}".format(predictions.shape))

# Plot: using the utility funcs.
class_readable_labels = cifar_builder.info.features['label'].names
top5_labels, top5_probs = process_predictions(predictions, class_readable_labels)

display_predicitons(images = img_batch,
                    topk_labels = top5_labels,
                    topk_probabilities = top5_probs)
# Out:
# predicted class probabilities: (16, 100)

# %% [markdown]
# ### Observation:
#
# The output predictions are now more accurate where the model was able to label these images more accurately. It does however still gets confused with some of the images similar to before but much less.
#
# ## Summary:
#
# Although this is not the end of this project, it does conclude the 1st notebook relevant to the theory of these advanced deep learning models. Please go to check out __Notebook 4__ for the __Keras Applications and reusing models__.
